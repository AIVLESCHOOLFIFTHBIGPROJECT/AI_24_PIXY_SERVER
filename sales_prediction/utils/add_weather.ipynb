# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

data2=pd.read_csv('../data/merged.csv')
data2

#나중에 parse받아서 입력받기
start_date = datetime(2013, 1, 1)
end_date = datetime(2013, 7, 31)

# %%
data2['date'] = pd.to_datetime(data2['date'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7128 entries, 0 to 7127
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   date                               7128 non-null   datetime64[ns]
#  1   sales                              7128 non-null   float64
#  2   year                               7128 non-null   int64
#  3   month                              7128 non-null   int64
#  4   day                                7128 non-null   int64
#  5   holiday                            7128 non-null   int64
#  6   family_AUTOMOTIVE                  7128 non-null   bool
#  7   family_BABY CARE                   7128 non-null   bool
#  8   family_BEAUTY                      7128 non-null   bool
#  9   family_BEVERAGES                   7128 non-null   bool
#  10  family_BOOKS                       7128 non-null   bool
# ...

# %%
import pandas as pd
import requests
from datetime import datetime, timedelta

# 1. 데이터셋 불러오기
# 예시로 데이터프레임을 만듭니다.
# 실제로는 pd.read_csv('your_dataset.csv') 등으로 데이터셋을 불러옵니다.
df=data2

# 2. OpenWeatherMap API 키 설정
api_key = '73ba0ccde8937bf812d9dd69ba9d194a'
city = 'Seoul'
base_url = 'http://api.openweathermap.org/data/2.5/weather'

# 3. 날짜별 날씨 정보 수집 함수
def get_weather_data(date):
    try:
        timestamp = int(datetime.strptime(date, '%Y-%m-%d').timestamp())
        params = {
            'q': city,
            'appid': api_key,
            'dt': timestamp
        }
        response = requests.get(base_url, params=params)
        data = response.json()
        if response.status_code == 200:
            return {
                'date': date,
                'weather': data['weather'][0]['description'],
                'temp': data['main']['temp'],
                'humidity': data['main']['humidity']
            }
        else:
            return {'date': date, 'weather': None, 'temp': None, 'humidity': None}
    except Exception as e:
        print(f"Error fetching data for {date}: {e}")
        return {'date': date, 'weather': None, 'temp': None, 'humidity': None}

# 4. 데이터프레임에 날씨 정보 추가
weather_data = []
for date in df['date']:
    weather_info = get_weather_data(date.strftime('%Y-%m-%d'))
    weather_data.append(weather_info)

weather_df = pd.DataFrame(weather_data)
merged_df = pd.merge(df, weather_df, on='date')

# 5. 데이터셋 저장
merged_df.to_csv('dataset_with_weather.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 42
#      40 weather_data = []
#      41 for date in df['date']:
# ---> 42     weather_info = get_weather_data(date.strftime('%Y-%m-%d'))
#      43     weather_data.append(weather_info)
#      45 weather_df = pd.DataFrame(weather_data)
#
# Cell In[14], line 24, in get_weather_data(date)
#      18 timestamp = int(datetime.strptime(date, '%Y-%m-%d').timestamp())
#      19 params = {
#      20     'q': city,
#      21     'appid': api_key,
#      22     'dt': timestamp
#      23 }
# ---> 24 response = requests.get(base_url, params=params)
#      25 data = response.json()
#      26 if response.status_code == 200:
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
# ...

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

API_KEY = '73ba0ccde8937bf812d9dd69ba9d194a'
city = 'Seoul'
start_date = datetime(2013, 1, 1)
end_date = datetime(2013, 7, 31)
delta = timedelta(days=1)

date_list = []
weather_data = []

current_date = start_date
# while current_date <= end_date:
date_list.append(current_date.strftime('%Y-%m-%d'))
response = requests.get(f'http://api.openweathermap.org/data/2.5/weather?q={city}&date={current_date.strftime("%Y-%m-%d")}&appid={API_KEY}')
data = response.json()
# print(data)
weather_data.append({
    'date': current_date.strftime('%Y-%m-%d'),
    'weather': data['weather'][0]['description'],
    'temp': data['main']['temp']
})
current_date += delta

weather_df = pd.DataFrame(weather_data)
weather_df.to_csv('seoul_weather.csv', index=False)

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# OpenWeatherMap API 키 설정
API_KEY = '73ba0ccde8937bf812d9dd69ba9d194a'
CITY = 'Seoul'
START_DATE = '2013-01-01'
END_DATE = '2013-07-31'

# 기간 설정
start_date = datetime.strptime(START_DATE, '%Y-%m-%d')
end_date = datetime.strptime(END_DATE, '%Y-%m-%d')

# 날씨 데이터를 저장할 리스트
weather_data = []

# API URL 설정
base_url = "http://api.openweathermap.org/data/2.5/weather"

# 날짜를 하루씩 증가시키며 API 호출
date = start_date
while date <= end_date:
    params = {
        'q': CITY,
        'appid': API_KEY,
        'units': 'metric',
        'dt': int(date.timestamp())
    }
    response = requests.get(base_url, params=params)
    data = response.json()
    
    # 필요한 데이터 추출
    if response.status_code == 200:
        weather_data.append({
            'date': date.strftime('%Y-%m-%d'),
            'temp': data['main']['temp'],
            'weather': data['weather'][0]['description']
        })
    
    # 날짜 하루 증가
    date += timedelta(days=1)

# 데이터프레임으로 변환
df = pd.DataFrame(weather_data)
print(df)
# Out:
#            date   temp               weather
# 0    2013-01-01  25.66  heavy intensity rain
# 1    2013-01-02  25.66  heavy intensity rain
# 2    2013-01-03  25.66  heavy intensity rain
# 3    2013-01-04  25.66  heavy intensity rain
# 4    2013-01-05  25.66  heavy intensity rain
# ..          ...    ...                   ...
# 207  2013-07-27  25.66  heavy intensity rain
# 208  2013-07-28  25.66  heavy intensity rain
# 209  2013-07-29  25.66  heavy intensity rain
# 210  2013-07-30  25.66  heavy intensity rain
# 211  2013-07-31  25.66  heavy intensity rain
#
# [212 rows x 3 columns]
